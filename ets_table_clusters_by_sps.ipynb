# %%
import pandas as pd

#d = pd.DataFrame.from_csv('ets_table_cluster_by_sps2.csv', header=0, sep=',')
d = pd.read_csv('ets_table_cluster_by_sps2.csv', header=0, sep=',')

d1 = d[d['c']>0]

d1
# Out:
#                                           t1                       t2   c
# 0                             uat_Tracts_754  ett_PostingItemLand_422   1
# 2                         ett_SystemName_105  ett_PostingItemLand_422   1
# 3                       cmd_PurchaseItem_551  ett_PostingItemLand_422   1
# 6                   ett_OASISProjectMaps_477  ett_PostingItemLand_422   2
# 7                          mat_Substance_654  ett_PostingItemLand_422   1
# 9                       cst_CISAgreement_601  ett_PostingItemLand_422   2
# 12            cst_ValidationOfferOptions_619  ett_PostingItemLand_422   1
# 14                          mat_WellType_652  ett_PostingItemLand_422   1
# 15             cst_CISApplicationSummary_618  ett_PostingItemLand_422   1
# 17             ett_OASISSupplementalDocs_486  ett_PostingItemLand_422   1
# 19                         oft_Extension_706  ett_PostingItemLand_422   1
# 21                              mat_Well_655  ett_PostingItemLand_422   1
# ...

# %%
##
## https://jakevdp.github.io/PythonDataScienceHandbook/04.02-simple-scatter-plots.html
    

import matplotlib.pyplot as plt
plt.scatter(d1['t1'], d1['t2'], c = d1['c']*10, sizes = d1['c'], alpha=0.3)
